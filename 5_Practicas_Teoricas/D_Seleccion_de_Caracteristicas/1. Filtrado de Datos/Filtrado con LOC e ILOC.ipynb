# %%
import pandas as pd

# %%
nba = pd.read_excel("Datos/nba.xlsx")
nba.head()
# Out:
#             Name            Team  Number Position   Age               Height  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0  2023-02-06 00:00:00
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0  2023-06-06 00:00:00
# 2   John Holland  Boston Celtics    30.0       SG  27.0  2023-05-06 00:00:00
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0  2023-05-06 00:00:00
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0  2023-10-06 00:00:00
#
#    Weight            College     Salary
# 0   180.0              Texas  7730337.0
# 1   235.0          Marquette  6796117.0
# 2   205.0  Boston University        NaN
# 3   185.0      Georgia State  1148640.0
# 4   231.0                NaN  5000000.0

# %%
nba.set_index("Team", inplace = True, drop = False) 
# Cuando transformo una columna en índice de un dataframe, ésta deja de ser una columna en sí. 
# Si queremos cambiar esto, debemos utilizar el argumento 'drop = False'

# %%
nba.head()
# Out:
#                          Name            Team  Number Position   Age  \
# Team
# Boston Celtics  Avery Bradley  Boston Celtics     0.0       PG  25.0
# Boston Celtics    Jae Crowder  Boston Celtics    99.0       SF  25.0
# Boston Celtics   John Holland  Boston Celtics    30.0       SG  27.0
# Boston Celtics    R.J. Hunter  Boston Celtics    28.0       SG  22.0
# Boston Celtics  Jonas Jerebko  Boston Celtics     8.0       PF  29.0
#
#                              Height  Weight            College     Salary
# Team
# Boston Celtics  2023-02-06 00:00:00   180.0              Texas  7730337.0
# Boston Celtics  2023-06-06 00:00:00   235.0          Marquette  6796117.0
# Boston Celtics  2023-05-06 00:00:00   205.0  Boston University        NaN
# Boston Celtics  2023-05-06 00:00:00   185.0      Georgia State  1148640.0
# Boston Celtics  2023-10-06 00:00:00   231.0                NaN  5000000.0

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 457 entries, Boston Celtics to Utah Jazz
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 35.7+ KB

# %%
nba["Team"].unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz'],
#       dtype=object)

# %% [markdown]
# ### LOC

# %%
nba.loc["Utah Jazz"] # El primer elemento hace referencia al índice.
# Out:
#                      Name       Team  Number Position   Age  \
# Team
# Utah Jazz   Trevor Booker  Utah Jazz    33.0       PF  28.0
# Utah Jazz      Trey Burke  Utah Jazz     3.0       PG  23.0
# Utah Jazz      Alec Burks  Utah Jazz    10.0       SG  24.0
# Utah Jazz      Dante Exum  Utah Jazz    11.0       PG  20.0
# Utah Jazz  Derrick Favors  Utah Jazz    15.0       PF  24.0
# Utah Jazz     Rudy Gobert  Utah Jazz    27.0        C  23.0
# Utah Jazz  Gordon Hayward  Utah Jazz    20.0       SF  26.0
# Utah Jazz     Rodney Hood  Utah Jazz     5.0       SG  23.0
# Utah Jazz      Joe Ingles  Utah Jazz     2.0       SF  28.0
# Utah Jazz   Chris Johnson  Utah Jazz    23.0       SF  26.0
# Utah Jazz      Trey Lyles  Utah Jazz    41.0       PF  20.0
# Utah Jazz    Shelvin Mack  Utah Jazz     8.0       PG  26.0
# Utah Jazz       Raul Neto  Utah Jazz    25.0       PG  24.0
# Utah Jazz    Tibor Pleiss  Utah Jazz    21.0        C  26.0
# ...

# %%
nba.loc["Chicago Bulls" : "Detroit Pistons"]
# Out:
#                                          Name                 Team  Number  \
# Team
# Chicago Bulls                Cameron Bairstow        Chicago Bulls    41.0
# Chicago Bulls                    Aaron Brooks        Chicago Bulls     0.0
# Chicago Bulls                    Jimmy Butler        Chicago Bulls    21.0
# Chicago Bulls                   Mike Dunleavy        Chicago Bulls    34.0
# Chicago Bulls               Cristiano Felicio        Chicago Bulls     6.0
# Chicago Bulls                       Pau Gasol        Chicago Bulls    16.0
# Chicago Bulls                      Taj Gibson        Chicago Bulls    22.0
# Chicago Bulls                  Justin Holiday        Chicago Bulls     7.0
# Chicago Bulls                  Doug McDermott        Chicago Bulls     3.0
# Chicago Bulls                  Nikola Mirotic        Chicago Bulls    44.0
# Chicago Bulls                   E'Twaun Moore        Chicago Bulls    55.0
# ...

# %%
nba.loc[: "Chicago Bulls"]
# Out:
#                          Name            Team  Number Position   Age  \
# Team
# Boston Celtics  Avery Bradley  Boston Celtics     0.0       PG  25.0
# Boston Celtics    Jae Crowder  Boston Celtics    99.0       SF  25.0
# Boston Celtics   John Holland  Boston Celtics    30.0       SG  27.0
# Boston Celtics    R.J. Hunter  Boston Celtics    28.0       SG  22.0
# Boston Celtics  Jonas Jerebko  Boston Celtics     8.0       PF  29.0
# ...                       ...             ...     ...      ...   ...
# Chicago Bulls   E'Twaun Moore   Chicago Bulls    55.0       SG  27.0
# Chicago Bulls     Joakim Noah   Chicago Bulls    13.0        C  31.0
# Chicago Bulls    Bobby Portis   Chicago Bulls     5.0       PF  21.0
# Chicago Bulls    Derrick Rose   Chicago Bulls     1.0       PG  27.0
# Chicago Bulls      Tony Snell   Chicago Bulls    20.0       SF  24.0
#
#                              Height  Weight            College      Salary
# Team
# ...

# %%
nba.loc[["Chicago Bulls", "Detroit Pistons"]]
# Out:
#                                      Name             Team  Number Position  \
# Team
# Chicago Bulls            Cameron Bairstow    Chicago Bulls    41.0       PF
# Chicago Bulls                Aaron Brooks    Chicago Bulls     0.0       PG
# Chicago Bulls                Jimmy Butler    Chicago Bulls    21.0       SG
# Chicago Bulls               Mike Dunleavy    Chicago Bulls    34.0       SG
# Chicago Bulls           Cristiano Felicio    Chicago Bulls     6.0       PF
# Chicago Bulls                   Pau Gasol    Chicago Bulls    16.0        C
# Chicago Bulls                  Taj Gibson    Chicago Bulls    22.0       PF
# Chicago Bulls              Justin Holiday    Chicago Bulls     7.0       SG
# Chicago Bulls              Doug McDermott    Chicago Bulls     3.0       SF
# Chicago Bulls              Nikola Mirotic    Chicago Bulls    44.0       PF
# Chicago Bulls               E'Twaun Moore    Chicago Bulls    55.0       SG
# ...

# %% [markdown]
# Consideraciones de la selección:
# *  Cuando son dos elementos continuos, se puede aplicar un slicing directamente: elemento_1 : elemento_2
# *  Cuando son dos elementos que no son continuos, se les debe pasar en una lista: [elemento_1, elemento_2, elemento_3]

# %%
nba.loc[["Chicago Bulls", "Detroit Pistons"], "Name" : "Position"]
# Out:
#                                      Name             Team  Number Position
# Team
# Chicago Bulls            Cameron Bairstow    Chicago Bulls    41.0       PF
# Chicago Bulls                Aaron Brooks    Chicago Bulls     0.0       PG
# Chicago Bulls                Jimmy Butler    Chicago Bulls    21.0       SG
# Chicago Bulls               Mike Dunleavy    Chicago Bulls    34.0       SG
# Chicago Bulls           Cristiano Felicio    Chicago Bulls     6.0       PF
# Chicago Bulls                   Pau Gasol    Chicago Bulls    16.0        C
# Chicago Bulls                  Taj Gibson    Chicago Bulls    22.0       PF
# Chicago Bulls              Justin Holiday    Chicago Bulls     7.0       SG
# Chicago Bulls              Doug McDermott    Chicago Bulls     3.0       SF
# Chicago Bulls              Nikola Mirotic    Chicago Bulls    44.0       PF
# Chicago Bulls               E'Twaun Moore    Chicago Bulls    55.0       SG
# ...

# %% [markdown]
# El loc acepta condiciones booleanas para su selección

# %%
nba.loc[(nba.Team == 'Chicago Bulls') | (nba.Age <25)]
# Out:
#                            Name            Team  Number Position   Age  \
# Team
# Boston Celtics      R.J. Hunter  Boston Celtics    28.0       SG  22.0
# Boston Celtics    Jordan Mickey  Boston Celtics    55.0       PF  21.0
# Boston Celtics     Terry Rozier  Boston Celtics    12.0       PG  22.0
# Boston Celtics     Marcus Smart  Boston Celtics    36.0       PG  22.0
# Boston Celtics  Jared Sullinger  Boston Celtics     7.0        C  24.0
# ...                         ...             ...     ...      ...   ...
# Utah Jazz        Derrick Favors       Utah Jazz    15.0       PF  24.0
# Utah Jazz           Rudy Gobert       Utah Jazz    27.0        C  23.0
# Utah Jazz           Rodney Hood       Utah Jazz     5.0       SG  23.0
# Utah Jazz            Trey Lyles       Utah Jazz    41.0       PF  20.0
# Utah Jazz             Raul Neto       Utah Jazz    25.0       PG  24.0
#
#                              Height  Weight         College      Salary
# Team
# ...

# %% [markdown]
# ## ILOC

# %%
nba.iloc[3]
# Out:
# Name                R.J. Hunter
# Team             Boston Celtics
# Number                     28.0
# Position                     SG
# Age                        22.0
# Height      2023-05-06 00:00:00
# Weight                    185.0
# College           Georgia State
# Salary                1148640.0
# Name: Boston Celtics, dtype: object

# %%
nba.iloc[0:3] # Recordar que el iloc no trae el último elemento solicitado
# Out:
#                          Name            Team  Number Position   Age  \
# Team
# Boston Celtics  Avery Bradley  Boston Celtics     0.0       PG  25.0
# Boston Celtics    Jae Crowder  Boston Celtics    99.0       SF  25.0
# Boston Celtics   John Holland  Boston Celtics    30.0       SG  27.0
#
#                              Height  Weight            College     Salary
# Team
# Boston Celtics  2023-02-06 00:00:00   180.0              Texas  7730337.0
# Boston Celtics  2023-06-06 00:00:00   235.0          Marquette  6796117.0
# Boston Celtics  2023-05-06 00:00:00   205.0  Boston University        NaN

# %%
nba.iloc[:3]
# Out:
#                          Name            Team  Number Position   Age  \
# Team
# Boston Celtics  Avery Bradley  Boston Celtics     0.0       PG  25.0
# Boston Celtics    Jae Crowder  Boston Celtics    99.0       SF  25.0
# Boston Celtics   John Holland  Boston Celtics    30.0       SG  27.0
#
#                              Height  Weight            College     Salary
# Team
# Boston Celtics  2023-02-06 00:00:00   180.0              Texas  7730337.0
# Boston Celtics  2023-06-06 00:00:00   235.0          Marquette  6796117.0
# Boston Celtics  2023-05-06 00:00:00   205.0  Boston University        NaN

# %%
nba.iloc[[0,2]]
# Out:
#                          Name            Team  Number Position   Age  \
# Team
# Boston Celtics  Avery Bradley  Boston Celtics     0.0       PG  25.0
# Boston Celtics   John Holland  Boston Celtics    30.0       SG  27.0
#
#                              Height  Weight            College     Salary
# Team
# Boston Celtics  2023-02-06 00:00:00   180.0              Texas  7730337.0
# Boston Celtics  2023-05-06 00:00:00   205.0  Boston University        NaN

# %%
nba.iloc[:3, :]
# Out:
#                          Name            Team  Number Position   Age  \
# Team
# Boston Celtics  Avery Bradley  Boston Celtics     0.0       PG  25.0
# Boston Celtics    Jae Crowder  Boston Celtics    99.0       SF  25.0
# Boston Celtics   John Holland  Boston Celtics    30.0       SG  27.0
#
#                              Height  Weight            College     Salary
# Team
# Boston Celtics  2023-02-06 00:00:00   180.0              Texas  7730337.0
# Boston Celtics  2023-06-06 00:00:00   235.0          Marquette  6796117.0
# Boston Celtics  2023-05-06 00:00:00   205.0  Boston University        NaN

# %%
nba.iloc[:3, [0,2,5]]
# Out:
#                          Name  Number               Height
# Team
# Boston Celtics  Avery Bradley     0.0  2023-02-06 00:00:00
# Boston Celtics    Jae Crowder    99.0  2023-06-06 00:00:00
# Boston Celtics   John Holland    30.0  2023-05-06 00:00:00

# %%
nba.iloc[:, [2,4,5]]
# Out:
#                 Number   Age               Height
# Team
# Boston Celtics     0.0  25.0  2023-02-06 00:00:00
# Boston Celtics    99.0  25.0  2023-06-06 00:00:00
# Boston Celtics    30.0  27.0  2023-05-06 00:00:00
# Boston Celtics    28.0  22.0  2023-05-06 00:00:00
# Boston Celtics     8.0  29.0  2023-10-06 00:00:00
# ...                ...   ...                  ...
# Utah Jazz         41.0  20.0  2023-10-06 00:00:00
# Utah Jazz          8.0  26.0  2023-03-06 00:00:00
# Utah Jazz         25.0  24.0  2023-01-06 00:00:00
# Utah Jazz         21.0  26.0  2023-03-07 00:00:00
# Utah Jazz         24.0  26.0                  7-0
#
# [457 rows x 3 columns]

# %%
nba["Team"]
# Out:
# Team
# Boston Celtics    Boston Celtics
# Boston Celtics    Boston Celtics
# Boston Celtics    Boston Celtics
# Boston Celtics    Boston Celtics
# Boston Celtics    Boston Celtics
#                        ...
# Utah Jazz              Utah Jazz
# Utah Jazz              Utah Jazz
# Utah Jazz              Utah Jazz
# Utah Jazz              Utah Jazz
# Utah Jazz              Utah Jazz
# Name: Team, Length: 457, dtype: object

# %%
nba[["Team", "Name", "College", "Salary"]]
# Out:
#                           Team           Name            College     Salary
# Team
# Boston Celtics  Boston Celtics  Avery Bradley              Texas  7730337.0
# Boston Celtics  Boston Celtics    Jae Crowder          Marquette  6796117.0
# Boston Celtics  Boston Celtics   John Holland  Boston University        NaN
# Boston Celtics  Boston Celtics    R.J. Hunter      Georgia State  1148640.0
# Boston Celtics  Boston Celtics  Jonas Jerebko                NaN  5000000.0
# ...                        ...            ...                ...        ...
# Utah Jazz            Utah Jazz     Trey Lyles           Kentucky  2239800.0
# Utah Jazz            Utah Jazz   Shelvin Mack             Butler  2433333.0
# Utah Jazz            Utah Jazz      Raul Neto                NaN   900000.0
# Utah Jazz            Utah Jazz   Tibor Pleiss                NaN  2900000.0
# Utah Jazz            Utah Jazz    Jeff Withey             Kansas   947276.0
#
# [457 rows x 4 columns]

# %%
seleccion = ["Team", "Name", "College", "Salary"]
nba[seleccion]
# Out:
#                           Team           Name            College     Salary
# Team
# Boston Celtics  Boston Celtics  Avery Bradley              Texas  7730337.0
# Boston Celtics  Boston Celtics    Jae Crowder          Marquette  6796117.0
# Boston Celtics  Boston Celtics   John Holland  Boston University        NaN
# Boston Celtics  Boston Celtics    R.J. Hunter      Georgia State  1148640.0
# Boston Celtics  Boston Celtics  Jonas Jerebko                NaN  5000000.0
# ...                        ...            ...                ...        ...
# Utah Jazz            Utah Jazz     Trey Lyles           Kentucky  2239800.0
# Utah Jazz            Utah Jazz   Shelvin Mack             Butler  2433333.0
# Utah Jazz            Utah Jazz      Raul Neto                NaN   900000.0
# Utah Jazz            Utah Jazz   Tibor Pleiss                NaN  2900000.0
# Utah Jazz            Utah Jazz    Jeff Withey             Kansas   947276.0
#
# [457 rows x 4 columns]

# %%
nba["Team"] == "Boston Celtics"
# Out:
# Team
# Boston Celtics     True
# Boston Celtics     True
# Boston Celtics     True
# Boston Celtics     True
# Boston Celtics     True
#                   ...
# Utah Jazz         False
# Utah Jazz         False
# Utah Jazz         False
# Utah Jazz         False
# Utah Jazz         False
# Name: Team, Length: 457, dtype: bool

# %%
nba[nba["Team"] == "Boston Celtics"]
# Out:
#                            Name            Team  Number Position   Age  \
# Team
# Boston Celtics    Avery Bradley  Boston Celtics     0.0       PG  25.0
# Boston Celtics      Jae Crowder  Boston Celtics    99.0       SF  25.0
# Boston Celtics     John Holland  Boston Celtics    30.0       SG  27.0
# Boston Celtics      R.J. Hunter  Boston Celtics    28.0       SG  22.0
# Boston Celtics    Jonas Jerebko  Boston Celtics     8.0       PF  29.0
# Boston Celtics     Amir Johnson  Boston Celtics    90.0       PF  29.0
# Boston Celtics    Jordan Mickey  Boston Celtics    55.0       PF  21.0
# Boston Celtics     Kelly Olynyk  Boston Celtics    41.0        C  25.0
# Boston Celtics     Terry Rozier  Boston Celtics    12.0       PG  22.0
# Boston Celtics     Marcus Smart  Boston Celtics    36.0       PG  22.0
# Boston Celtics  Jared Sullinger  Boston Celtics     7.0        C  24.0
# Boston Celtics    Isaiah Thomas  Boston Celtics     4.0       PG  27.0
# ...

# %%
condicion = nba["Team"] == "Boston Celtics"
nba[condicion]
# Out:
#                            Name            Team  Number Position   Age  \
# Team
# Boston Celtics    Avery Bradley  Boston Celtics     0.0       PG  25.0
# Boston Celtics      Jae Crowder  Boston Celtics    99.0       SF  25.0
# Boston Celtics     John Holland  Boston Celtics    30.0       SG  27.0
# Boston Celtics      R.J. Hunter  Boston Celtics    28.0       SG  22.0
# Boston Celtics    Jonas Jerebko  Boston Celtics     8.0       PF  29.0
# Boston Celtics     Amir Johnson  Boston Celtics    90.0       PF  29.0
# Boston Celtics    Jordan Mickey  Boston Celtics    55.0       PF  21.0
# Boston Celtics     Kelly Olynyk  Boston Celtics    41.0        C  25.0
# Boston Celtics     Terry Rozier  Boston Celtics    12.0       PG  22.0
# Boston Celtics     Marcus Smart  Boston Celtics    36.0       PG  22.0
# Boston Celtics  Jared Sullinger  Boston Celtics     7.0        C  24.0
# Boston Celtics    Isaiah Thomas  Boston Celtics     4.0       PG  27.0
# ...

# %%
condicion_1 = nba["Team"] == "Boston Celtics"
condicion_2 = nba["Age"] < 25
nba[condicion_1 & condicion_2]
# Out:
#                            Name            Team  Number Position   Age  \
# Team
# Boston Celtics      R.J. Hunter  Boston Celtics    28.0       SG  22.0
# Boston Celtics    Jordan Mickey  Boston Celtics    55.0       PF  21.0
# Boston Celtics     Terry Rozier  Boston Celtics    12.0       PG  22.0
# Boston Celtics     Marcus Smart  Boston Celtics    36.0       PG  22.0
# Boston Celtics  Jared Sullinger  Boston Celtics     7.0        C  24.0
# Boston Celtics      James Young  Boston Celtics    13.0       SG  20.0
#
#                              Height  Weight         College     Salary
# Team
# Boston Celtics  2023-05-06 00:00:00   185.0   Georgia State  1148640.0
# Boston Celtics  2023-08-06 00:00:00   235.0             LSU  1170960.0
# Boston Celtics  2023-02-06 00:00:00   190.0      Louisville  1824360.0
# Boston Celtics  2023-04-06 00:00:00   220.0  Oklahoma State  3431040.0
# Boston Celtics  2023-09-06 00:00:00   260.0      Ohio State  2569260.0
# ...

# %%
condicion_1 = nba["Team"] == "Boston Celtics"
condicion_2 = nba["Age"] < 25
condicion_3 = nba["Salary"] > 5000000
nba[condicion_1 & (condicion_2 | condicion_3)] # Para establecer un orden de condiciones, se pueden utilizar paréntesis
# Out:
#                            Name            Team  Number Position   Age  \
# Team
# Boston Celtics    Avery Bradley  Boston Celtics     0.0       PG  25.0
# Boston Celtics      Jae Crowder  Boston Celtics    99.0       SF  25.0
# Boston Celtics      R.J. Hunter  Boston Celtics    28.0       SG  22.0
# Boston Celtics     Amir Johnson  Boston Celtics    90.0       PF  29.0
# Boston Celtics    Jordan Mickey  Boston Celtics    55.0       PF  21.0
# Boston Celtics     Terry Rozier  Boston Celtics    12.0       PG  22.0
# Boston Celtics     Marcus Smart  Boston Celtics    36.0       PG  22.0
# Boston Celtics  Jared Sullinger  Boston Celtics     7.0        C  24.0
# Boston Celtics    Isaiah Thomas  Boston Celtics     4.0       PG  27.0
# Boston Celtics      James Young  Boston Celtics    13.0       SG  20.0
#
#                              Height  Weight         College      Salary
# Team
# Boston Celtics  2023-02-06 00:00:00   180.0           Texas   7730337.0
# ...
