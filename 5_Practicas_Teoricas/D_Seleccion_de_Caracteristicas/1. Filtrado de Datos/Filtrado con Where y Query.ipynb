# %%
import pandas as pd

# %%
nba = pd.read_excel("Datos/nba.xlsx")
nba.head()
# Out:
#             Name            Team  Number Position   Age               Height  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0  2023-02-06 00:00:00
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0  2023-06-06 00:00:00
# 2   John Holland  Boston Celtics    30.0       SG  27.0  2023-05-06 00:00:00
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0  2023-05-06 00:00:00
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0  2023-10-06 00:00:00
#
#    Weight            College     Salary
# 0   180.0              Texas  7730337.0
# 1   235.0          Marquette  6796117.0
# 2   205.0  Boston University        NaN
# 3   185.0      Georgia State  1148640.0
# 4   231.0                NaN  5000000.0

# %%
nba.set_index("Team", inplace = True, drop = False) 
# Cuando transformo una columna en índice de un dataframe, ésta deja de ser una columna en sí. 
# Si queremos cambiar esto, debemos utilizar el argumento 'drop = False'

# %% [markdown]
# ### Función where

# %%
nba.where(nba["Salary"] < 5000000, other = 0)
# Out:
#                         Name            Team  Number Position   Age  \
# Team
# Boston Celtics             0               0     0.0        0   0.0
# Boston Celtics             0               0     0.0        0   0.0
# Boston Celtics             0               0     0.0        0   0.0
# Boston Celtics   R.J. Hunter  Boston Celtics    28.0       SG  22.0
# Boston Celtics             0               0     0.0        0   0.0
# ...                      ...             ...     ...      ...   ...
# Utah Jazz         Trey Lyles       Utah Jazz    41.0       PF  20.0
# Utah Jazz       Shelvin Mack       Utah Jazz     8.0       PG  26.0
# Utah Jazz          Raul Neto       Utah Jazz    25.0       PG  24.0
# Utah Jazz       Tibor Pleiss       Utah Jazz    21.0        C  26.0
# Utah Jazz        Jeff Withey       Utah Jazz    24.0        C  26.0
#
#                              Height  Weight        College     Salary
# Team
# ...

# %% [markdown]
# ### Función query

# %%
nba.query('Salary < 5000000')
# Out:
#                          Name            Team  Number Position   Age  \
# Team
# Boston Celtics    R.J. Hunter  Boston Celtics    28.0       SG  22.0
# Boston Celtics  Jordan Mickey  Boston Celtics    55.0       PF  21.0
# Boston Celtics   Kelly Olynyk  Boston Celtics    41.0        C  25.0
# Boston Celtics   Terry Rozier  Boston Celtics    12.0       PG  22.0
# Boston Celtics   Marcus Smart  Boston Celtics    36.0       PG  22.0
# ...                       ...             ...     ...      ...   ...
# Utah Jazz          Trey Lyles       Utah Jazz    41.0       PF  20.0
# Utah Jazz        Shelvin Mack       Utah Jazz     8.0       PG  26.0
# Utah Jazz           Raul Neto       Utah Jazz    25.0       PG  24.0
# Utah Jazz        Tibor Pleiss       Utah Jazz    21.0        C  26.0
# Utah Jazz         Jeff Withey       Utah Jazz    24.0        C  26.0
#
#                              Height  Weight         College     Salary
# Team
# ...

# %%
condicion = nba["Team"].isin(["Boston Celtics", "Chicago Bulls", "Utah Jazz"]) # Para buscar una cierta cantidad de elementos
nba[condicion]
# Out:
#                              Name            Team  Number Position   Age  \
# Team
# Boston Celtics      Avery Bradley  Boston Celtics     0.0       PG  25.0
# Boston Celtics        Jae Crowder  Boston Celtics    99.0       SF  25.0
# Boston Celtics       John Holland  Boston Celtics    30.0       SG  27.0
# Boston Celtics        R.J. Hunter  Boston Celtics    28.0       SG  22.0
# Boston Celtics      Jonas Jerebko  Boston Celtics     8.0       PF  29.0
# Boston Celtics       Amir Johnson  Boston Celtics    90.0       PF  29.0
# Boston Celtics      Jordan Mickey  Boston Celtics    55.0       PF  21.0
# Boston Celtics       Kelly Olynyk  Boston Celtics    41.0        C  25.0
# Boston Celtics       Terry Rozier  Boston Celtics    12.0       PG  22.0
# Boston Celtics       Marcus Smart  Boston Celtics    36.0       PG  22.0
# Boston Celtics    Jared Sullinger  Boston Celtics     7.0        C  24.0
# Boston Celtics      Isaiah Thomas  Boston Celtics     4.0       PG  27.0
# ...

# %%
condicion = nba["Team"].isin(["Boston Celtics", "Chicago Bulls", "Utah Jazz"]) # En caso de querer filtrar por la negativa, ponemos el símbolo de equivalente adelante
nba[~condicion]
# Out:
#                                            Name                    Team  \
# Team
# Brooklyn Nets                  Bojan Bogdanovic           Brooklyn Nets
# Brooklyn Nets                      Markel Brown           Brooklyn Nets
# Brooklyn Nets                   Wayne Ellington           Brooklyn Nets
# Brooklyn Nets           Rondae Hollis-Jefferson           Brooklyn Nets
# Brooklyn Nets                      Jarrett Jack           Brooklyn Nets
# ...                                         ...                     ...
# Portland Trail Blazers            C.J. McCollum  Portland Trail Blazers
# Portland Trail Blazers             Luis Montero  Portland Trail Blazers
# Portland Trail Blazers            Mason Plumlee  Portland Trail Blazers
# Portland Trail Blazers            Brian Roberts  Portland Trail Blazers
# Portland Trail Blazers              Noah Vonleh  Portland Trail Blazers
#
#                         Number Position   Age               Height  Weight  \
# Team
# ...

# %%
# Para simular el 'like' de sql, se puede utilizar la función contains.
# Hay que aclarar qué se busca, qué se hace con los NA, y si es sensible a las mayúsculas
condicion = nba["Team"].str.contains("boston", na = False, case = False)
nba[condicion]
# Out:
#                            Name            Team  Number Position   Age  \
# Team
# Boston Celtics    Avery Bradley  Boston Celtics     0.0       PG  25.0
# Boston Celtics      Jae Crowder  Boston Celtics    99.0       SF  25.0
# Boston Celtics     John Holland  Boston Celtics    30.0       SG  27.0
# Boston Celtics      R.J. Hunter  Boston Celtics    28.0       SG  22.0
# Boston Celtics    Jonas Jerebko  Boston Celtics     8.0       PF  29.0
# Boston Celtics     Amir Johnson  Boston Celtics    90.0       PF  29.0
# Boston Celtics    Jordan Mickey  Boston Celtics    55.0       PF  21.0
# Boston Celtics     Kelly Olynyk  Boston Celtics    41.0        C  25.0
# Boston Celtics     Terry Rozier  Boston Celtics    12.0       PG  22.0
# Boston Celtics     Marcus Smart  Boston Celtics    36.0       PG  22.0
# Boston Celtics  Jared Sullinger  Boston Celtics     7.0        C  24.0
# Boston Celtics    Isaiah Thomas  Boston Celtics     4.0       PG  27.0
# ...

# %% [markdown]
# Ejemplo - Extra

# %%
df = pd.read_excel("Datos/employees.xlsx", parse_dates = ["Start Date", "Last Login Time"])
df.head(3)
# Out:
# C:\Users\JORGE LUIS\AppData\Local\Temp\ipykernel_11632\379777392.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_excel("Datos/employees.xlsx", parse_dates = ["Start Date", "Last Login Time"])
#   First Name  Gender           Start Date     Last Login Time  Salary Bonus %  \
# 0    Douglas    Male  1993-06-08 00:00:00 2024-10-20 12:42:00   97308    6945
# 1     Thomas    Male            3/31/1996 2024-10-20 06:53:00   61933    4.17
# 2      Maria  Female            4/23/1993 2024-10-20 11:17:00  130590   11858
#
#    Senior Management       Team
# 0                1.0  Marketing
# 1                1.0        NaN
# 2                0.0    Finance

# %%
df[df["Salary"].between(60000,70000)]
# Out:
#     First Name  Gender           Start Date     Last Login Time  Salary  \
# 1       Thomas    Male            3/31/1996 2024-10-20 06:53:00   61933
# 6         Ruby  Female            8/17/1987 2024-10-20 16:20:00   65476
# 10      Louise  Female  1980-12-08 00:00:00 2024-10-20 09:01:00   63241
# 20        Lois     NaN            4/22/1995 2024-10-20 19:18:00   64714
# 41   Christine     NaN            6/28/2015 2024-10-20 01:08:00   66582
# ..         ...     ...                  ...                 ...     ...
# 965  Catherine  Female            9/25/1989 2024-10-20 01:31:00   68164
# 970      Alice  Female  1988-03-09 00:00:00 2024-10-20 20:54:00   63571
# 974      Harry    Male            8/30/2011 2024-10-20 18:31:00   67656
# 978       Sean    Male            1/17/1983 2024-10-20 14:23:00   66146
# 998      Larry    Male            4/20/2013 2024-10-20 16:45:00   60500
#
#     Bonus %  Senior Management                  Team
# ...

# %%
df[df["Bonus %"].between(2.0, 5.0)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df[df["Bonus %"].between(2.0, 5.0)]
#
# File c:\Users\JORGE LUIS\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:5629, in Series.between(self, left, right, inclusive)
#    5561 """
#    5562 Return boolean Series equivalent to left <= series <= right.
#    5563
#    (...)
#    5626 dtype: bool
#    5627 """
#    5628 if inclusive == "both":
# -> 5629     lmask = self >= left
#    5630     rmask = self <= right
#    5631 elif inclusive == "left":
#
# File c:\Users\JORGE LUIS\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# ...

# %%
condicion = df["Start Date"].between("1991-01-01", "1992-01-01")
df[condicion]
# Out:
#     First Name  Gender           Start Date     Last Login Time  Salary  \
# 27       Scott     NaN  1991-11-07 00:00:00 2024-10-20 18:58:00  122367
# 75      Bonnie  Female  1991-02-07 00:00:00 2024-10-20 01:27:00  104897
# 166        NaN  Female  1991-09-07 00:00:00 2024-10-20 18:52:00   42341
# 245     Victor    Male  1991-11-04 00:00:00 2024-10-20 07:44:00   70817
# 313       Judy  Female  1991-01-07 00:00:00 2024-10-20 02:33:00  109510
# 552    Barbara  Female  1991-02-09 00:00:00 2024-10-20 15:41:00  127297
# 639     Amanda     NaN  1991-11-08 00:00:00 2024-10-20 14:15:00   46665
# 704     Thomas    Male  1991-07-09 00:00:00 2024-10-20 09:51:00   65251
# 909     Donald    Male  1991-01-08 00:00:00 2024-10-20 02:25:00   61999
# 989     Justin     NaN  1991-10-02 00:00:00 2024-10-20 16:58:00   38344
#
#     Bonus %  Senior Management             Team
# 27     5218                0.0            Legal
# 75     5118                1.0  Human Resources
# ...

# %%
condicion = df["Last Login Time"].between("08:30AM", "12:00PM")
df[condicion]
# Out:
#     First Name  Gender           Start Date     Last Login Time  Salary  \
# 2        Maria  Female            4/23/1993 2024-10-20 11:17:00  130590
# 7          NaN  Female            7/20/2015 2024-10-20 10:43:00   45906
# 10      Louise  Female  1980-12-08 00:00:00 2024-10-20 09:01:00   63241
# 18       Diana  Female           10/23/1981 2024-10-20 10:27:00  132940
# 33        Jean  Female           12/18/1993 2024-10-20 09:07:00  119082
# ..         ...     ...                  ...                 ...     ...
# 963        Ann  Female            9/23/1994 2024-10-20 11:15:00   89443
# 977      Sarah  Female  1995-04-12 00:00:00 2024-10-20 09:16:00  124566
# 982       Rose  Female  1982-06-04 00:00:00 2024-10-20 10:43:00   91411
# 988      Alice  Female  2004-05-10 00:00:00 2024-10-20 09:34:00   47638
# 992    Anthony    Male           10/16/2011 2024-10-20 08:35:00  112769
#
#     Bonus %  Senior Management                  Team
# ...
